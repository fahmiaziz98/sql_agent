# %%
import pandas as pd

df = pd.read_csv("../data/few-shot/prompts_intent.csv")
df.head(30)
# Out:
#                                                prompt  \
# 0   Need all the bookings from 10th to 15th Octobe...
# 1   Could you retrieve reservations for mid-Octobe...
# 2   Let’s see all the October reservations from 10...
# 3     Any reservations from 10/10/2023 to 15/10/2023?
# 4   I’m looking for bookings between the second an...
# 5              Who made a reservation last Wednesday?
# 6   Name the people who have booked a flight in th...
# 7    Who secured a flight reservation this past week?
# 8    Give me the names of last week's flight bookers.
# 9   Can you identify the individuals who booked a ...
# 10  What was our earning from confirmed bookings i...
# 11  How much income did we generate from bookings ...
# 12  What's the total revenue from confirmed transa...
# 13  Find out the total income from confirmed booki...
# 14  I want to know the total revenue from confirme...
# 15  In 2023, which month witnessed the highest num...
# ...
